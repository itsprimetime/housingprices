# %% [markdown]
# ### 1. Read in the Aimes housing data set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.linear_model import Ridge

np.random.seed(42)

# %%
df = pd.read_csv('../datasets/train.csv', index_col='Id')

# %% [markdown]
# ### 2. Conduct exploratory data analysis on this data set.

# %%
df.head()
# Out:
#            PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 109  533352170           60        RL           NaN     13517   Pave   NaN
# 544  531379050           60        RL          43.0     11492   Pave   NaN
# 153  535304180           20        RL          68.0      7922   Pave   NaN
# 318  916386060           60        RL          73.0      9802   Pave   NaN
# 255  906425045           50        RL          82.0     14235   Pave   NaN
#
#     Lot Shape Land Contour Utilities    ...     Screen Porch Pool Area  \
# Id                                      ...
# 109       IR1          Lvl    AllPub    ...                0         0
# 544       IR1          Lvl    AllPub    ...                0         0
# 153       Reg          Lvl    AllPub    ...                0         0
# 318       Reg          Lvl    AllPub    ...                0         0
# 255       IR1          Lvl    AllPub    ...                0         0
#
# ...

# %% [markdown]
# ### Lowercase Columns and Replace Spaces with Underscores

# %%
df.columns = map(str.lower, df.columns)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.rename(columns = {'saleprice':'sale_price'}, inplace=True)

# %%
df.columns
# Out:
# Index(['pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
# ...

# %%
df.shape
# Out:
# (2051, 80)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 109 to 10
# Data columns (total 80 columns):
# pid                2051 non-null int64
# ms_subclass        2051 non-null int64
# ms_zoning          2051 non-null object
# lot_frontage       1721 non-null float64
# lot_area           2051 non-null int64
# street             2051 non-null object
# alley              2051 non-null object
# lot_shape          2051 non-null object
# land_contour       2051 non-null object
# utilities          2051 non-null object
# lot_config         2051 non-null object
# land_slope         2051 non-null object
# neighborhood       2051 non-null object
# condition_1        2051 non-null object
# condition_2        2051 non-null object
# bldg_type          2051 non-null object
# house_style        2051 non-null object
# overall_qual       2051 non-null int64
# overall_cond       2051 non-null int64
# year_built         2051 non-null int64
# year_remod/add     2051 non-null int64
# ...

# %% [markdown]
# #### Fill NA for all values

# %%
df.fillna({'alley':'None',
          }, inplace=True)

df.fillna({'fireplace_qu':'None'}, inplace=True)

df.fillna({'garage_cond':'None'}, inplace=True)

df.fillna({'pool_qc':'None'}, inplace=True)

df.fillna({'fence':'None'}, inplace=True)

df.fillna({'misc_feature':'None'}, inplace=True)
# df['lot_frontage'].describe()
df.fillna({'lot_frontage':(.01*df['lot_area'])}, inplace=True) # lot_frontage_calc = .01* df['lot_area']

df.fillna({'mas_vnr_type':'None'}, inplace=True)

df.fillna({'mas_vnr_area':0}, inplace=True)

df.fillna({'bsmt_qual':'None'}, inplace=True)

df.fillna({'bsmt_cond':'None'}, inplace=True)

df.fillna({'bsmt_exposure':'None'}, inplace=True)

df.fillna({'bsmtfin_type_1':'None'}, inplace=True)

df.fillna({'bsmtfin_sf_1':0}, inplace=True)

df.fillna({'bsmtfin_type_2':'None'}, inplace=True)

df.fillna({'bsmtfin_sf_2':0}, inplace=True)

df.fillna({'bsmt_unf_sf':0}, inplace=True)

df.fillna({'total_bsmt_sf':0}, inplace=True)

df.fillna({'bsmt_full_bath':'None'}, inplace=True)

df.fillna({'bsmt_half_bath':'None'}, inplace=True)

df.fillna({'garage_type':'None'}, inplace=True)

df.fillna({'garage_finish':'None'}, inplace=True)

df.fillna({'garage_qual':'None'}, inplace=True)         

df.fillna({'garage_cars':0}, inplace=True)         

df.fillna({'garage_area':0}, inplace=True)

# %%
df.drop(['garage_yr_blt'], axis=1, inplace=True)

# %% [markdown]
# #### We drop the column garage_yr_blt because we don't think it has a large impact on sale price.

# %% [markdown]
# ### Look at our Features after we fill all nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 109 to 10
# Data columns (total 79 columns):
# pid                2051 non-null int64
# ms_subclass        2051 non-null int64
# ms_zoning          2051 non-null object
# lot_frontage       2051 non-null float64
# lot_area           2051 non-null int64
# street             2051 non-null object
# alley              2051 non-null object
# lot_shape          2051 non-null object
# land_contour       2051 non-null object
# utilities          2051 non-null object
# lot_config         2051 non-null object
# land_slope         2051 non-null object
# neighborhood       2051 non-null object
# condition_1        2051 non-null object
# condition_2        2051 non-null object
# bldg_type          2051 non-null object
# house_style        2051 non-null object
# overall_qual       2051 non-null int64
# overall_cond       2051 non-null int64
# year_built         2051 non-null int64
# year_remod/add     2051 non-null int64
# ...

# %% [markdown]
# Lot Frontage: many values appear to be around 1% of the lot area so I use that calculation to fill in the missing values. Otherwise I can use 0.

# %% [markdown]
# ### There are non-numeric columns with lots of values.

# %%
# df = df.select_dtypes(exclude='object') # Here we are only returning numeric columns

# %%
df.shape #Seeing how many columns were lost.
# Out:
# (2051, 80)

# %%
df.isnull().sum()
# Out:
# pid                  0
# ms_subclass          0
# ms_zoning            0
# lot_frontage       330
# lot_area             0
# street               0
# alley             1911
# lot_shape            0
# land_contour         0
# utilities            0
# lot_config           0
# land_slope           0
# neighborhood         0
# condition_1          0
# condition_2          0
# bldg_type            0
# house_style          0
# overall_qual         0
# overall_cond         0
# year_built           0
# year_remod/add       0
# roof_style           0
# roof_matl            0
# exterior_1st         0
# exterior_2nd         0
# mas_vnr_type        22
# mas_vnr_area        22
# exter_qual           0
# exter_cond           0
# foundation           0
#                   ...
# half_bath            0
# bedroom_abvgr        0
# kitchen_abvgr        0
# kitchen_qual         0
# totrms_abvgrd        0
# functional           0
# fireplaces           0
# fireplace_qu      1000
# garage_type        113
# ...

# %%
df.fillna({'enclosed_porhc': 0})
# Out:
#             pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# Id
# 109   533352170           60        RL           NaN     13517   Pave   NaN
# 544   531379050           60        RL          43.0     11492   Pave   NaN
# 153   535304180           20        RL          68.0      7922   Pave   NaN
# 318   916386060           60        RL          73.0      9802   Pave   NaN
# 255   906425045           50        RL          82.0     14235   Pave   NaN
# 138   535126040           20        RL         137.0     16492   Pave   NaN
# 2827  908186070          180        RM          35.0      3675   Pave   NaN
# 145   535154050           20        RL           NaN     12160   Pave   NaN
# 1942  535353130           20        RL           NaN     15783   Pave   NaN
# 1956  535426130           60        RL          70.0     11606   Pave   NaN
# 1044  527451290          160        RM          21.0      1680   Pave   NaN
# ...

# %%
# df.dropna(axis=1, inplace=True) # drop all columns with null values

# %%
df.shape
# Out:
# (2051, 80)

# %% [markdown]
# #### There are several columns that are empty or have 0 as a value. We should drop or fill these. First, I will evaluate how well they correlate to our target: price.

# %% [markdown]
# ### 3. My goal is to predict the price of a home. Here are a list of variables that I think will qualify as predictors of price in an SLR model.
#
# For each of the variables I believe to be a valid potential predictor in an SLR model, I generate a plot showing the relationship between the independent and dependent variables.

# %%
df.corr().round(2)
# Out:
#                   pid  ms_subclass  lot_frontage  lot_area  overall_qual  \
# pid              1.00        -0.00         -0.09      0.02         -0.27
# ms_subclass     -0.00         1.00         -0.39     -0.25          0.04
# lot_frontage    -0.09        -0.39          1.00      0.57          0.19
# lot_area         0.02        -0.25          0.57      1.00          0.11
# overall_qual    -0.27         0.04          0.19      0.11          1.00
# overall_cond     0.11        -0.07         -0.05     -0.02         -0.08
# year_built      -0.35         0.04          0.11      0.04          0.60
# year_remod/add  -0.18         0.04          0.09      0.05          0.58
# mas_vnr_area    -0.25        -0.00          0.22      0.17          0.44
# bsmtfin_sf_1    -0.09        -0.06          0.21      0.22          0.28
# bsmtfin_sf_2    -0.01        -0.07          0.04      0.04         -0.03
# bsmt_unf_sf     -0.11        -0.14          0.13      0.04          0.28
# ...

# %% [markdown]
# ### I'm generating a correlation matrix to identify features of interest. Thus far, my features of interest include: features = lot area, overall quality, year built, year remodeled, 1st fl sqft, wooden deck.

# %%
# plt.hist(x='baths')
plt.figure(figsize=(20,10))
plt.hist(df['full_bath'], bins = 5)

plt.xlabel('Full Bath', fontsize=15)
plt.ylabel('Count', fontsize=16)
plt.title('Histogram Full Bath', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Histogram Full Bath')

# %%
plt.scatter(df['lot_area'], df['sale_price'])

# %%
plt.figure(figsize=(15,7))
plt.scatter(df['lot_area'], df['lot_area'])
plt.plot((df['lot_area'].min(), df['lot_area'].max()),(np.mean(df['sale_price']), np.mean(df['sale_price'])), color='r');
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.title('Can Lot Area Predict Home Prices?')
# Out:
# Text(0.5, 1.0, 'Can Lot Area Predict Home Prices?')

# %%
df.describe().T.round()
# Out:
#                   count         mean          std          min          25%  \
# pid              2051.0  713590006.0  188691838.0  526301100.0  528458140.0
# ms_subclass      2051.0         57.0         43.0         20.0         20.0
# lot_frontage     2051.0         78.0         57.0         15.0         60.0
# lot_area         2051.0      10065.0       6742.0       1300.0       7500.0
# overall_qual     2051.0          6.0          1.0          1.0          5.0
# overall_cond     2051.0          6.0          1.0          1.0          5.0
# year_built       2051.0       1972.0         30.0       1872.0       1954.0
# year_remod/add   2051.0       1984.0         21.0       1950.0       1964.0
# mas_vnr_area     2051.0         99.0        174.0          0.0          0.0
# bsmtfin_sf_1     2051.0        442.0        461.0          0.0          0.0
# bsmtfin_sf_2     2051.0         48.0        165.0          0.0          0.0
# ...

# %% [markdown]
# #### Save Clean data to Datasets

# %%
df.to_csv('../datasets/aimes_clean_data')

# %%
# features = lot area, overall quality, year built, year remodeled, 1st fl sqft, wooden dec

# %% [markdown]
# ### StatsModels

# %%
y = df['sale_price']    # what we want to predict (ie. price)
X = df['lot_area']      # feature

# %%
X = sm.add_constant(X)
X.head()
# Out:
#      const  lot_area
# Id
# 109    1.0     13517
# 544    1.0     11492
# 153    1.0      7922
# 318    1.0      9802
# 255    1.0     14235

# %% [markdown]
# ##### In StatsModels we have to manually add the y-intecept by hand by using the sm.add_constant() command.

# %%
# First we instantiate our model
model = sm.OLS(y, X)

# %%
# Then we fit our model to the data
# The process of fiting our model means calculating B_naught and Beta_one

model = model.fit()

# %%
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     197.6
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):           6.46e-43
# Time:                        02:05:41   Log-Likelihood:                -25952.
# No. Observations:                2051   AIC:                         5.191e+04
# Df Residuals:                    2049   BIC:                         5.192e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.464e+05   3004.345     48.723      0.000     1.4e+05    1.52e+05
# ...

# %% [markdown]
# ### Interpretation of the Slope and Intercept

# %% [markdown]
# ##### Our Beta_Naught is 146,400. This means that if lot area is 0, then we can expect the price of the home to be $146,000.
#
# ##### Our Beta_One is 3.28. This means that for every one unit change in lot_area, we can expect the sale price to increase by $3.48.
#
# ##### That said, we cannot use this model because there is strong multicolinearity.

# %% [markdown]
# ## Train/Test Split

# %%
df.columns
# Out:
# Index(['pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
X = df[['lot_area','full_bath', 'overall_qual']]
y = df['sale_price']

# %% [markdown]
# ### Before we Regularize our model let's see what overfitting looks like.

# %%
# select all the columns that are not the target
nc = [x for x in df.columns if x != 'sale_price']

# from sklearn.preprocessing import PolynomialFeatures

# X = df[nc] #these are the independent variabels. 
# y = df['sale_price'] # this is what we're trying to predict

# pf = PolynomialFeatures(degree = 2,
#                        interaction_only = True,
#                        include_bias = False)
# pf = pf.fit(X)
# Xoverfit = pf.transform(X) 

# print(X.shape)
# print(Xoverfit.shape)

# %% [markdown]
# ### Split our data into Train and Testing Sets

# %%
# X_train, X_test, y_train, y_test = train_test_split(X,
#                                                     y,
#                                                     test_size = .33,
#                                                     random_state = 42)

# print('X_train shape is: ' + str(X_train.shape))
# print('y_train shape is: ' + str(y_train.shape))
# print('X_test shape is: ' + str(X_test.shape))
# print('y_test shape is: ' + str(y_test.shape))

# X_overfit_train, X_overfit_test, y_overfit_train, y_overfit_test = train_test_split(Xoverfit,
#                                                                                     y,
#                                                                                     test_size = 0.33,
#                                                                                     random_state = 42)

# print('X_overfit_train shape is: ' + str(X_overfit_train.shape))
# print('y_overfit_train shape is: ' + str(y_overfit_train.shape))
# print('X_overfit_test shape is: ' + str(X_overfit_test.shape))
# print('y_overfit_test shape is: ' + str(y_overfit_test.shape))

# %% [markdown]
# ### Number of rows are the same in my _Train_Test and _Overfit_Train_Test Split; however the columns are different.

# %% [markdown]
# ## Before We Introduce Regularization

# %% [markdown]
# #### Standardizing predictors is required.
# #### We must use Standardization before Regularization.

# %%
# Instantiate Standard Scaler.
ss = StandardScaler()

# %%
# Fit Standard Scaler to data.
ss.fit(X_train)

# %%
# Transform data using Standard Scaler.
Z_train = pd.DataFrame(ss.transform(X_train), columns = X_train.columns)

# %%
Z_train.head()

# %% [markdown]
# ### Standard Scaler on Overfit Data

# %%
ss_overfit = StandardScaler()

# %%
# Fit Standard Scaler to overfit data AND transform in one step.
Z_overfit_train = pd.DataFrame(ss_overfit.fit_transform(X_overfit_train))

# %%
Z_overfit_train.head()

# %% [markdown]
# ### Visualize our alphas...

# %%
# def ridge_coefs(X, y, alphas):
    
#     # set up the list to hold the different sets of coefficients:
#     coefs = []
    
#     # Set up a ridge regression object
#     ridge_reg = Ridge()
    
#     # Iterate through the alphas fed into the function:
#     for a in alphas:
        
#         # On each alpha reset the ridge model's alpha to the current one:
#         ridge_reg.set_params(alpha=a)
        
#         # fit or refit the model on the provided X, y
#         ridge_reg.fit(X, y)
        
#         # Get out the coefficient list
#         coefs.append(ridge_reg.coef_)
        
#     return coefs

# # np.logspace gives us points between specified orders of magnitude on a logarithmic scale. It is base 10.
# r_alphas = np.logspace(0, 5, 200)

# # Get the coefficients for each alpha for the Ridge, using the function above
# r_coefs = ridge_coefs(X, y, r_alphas)

# # The cycler package lets us "cycle" through colors.
# # Just another thing I had to look up on stackoverflow. That's my life.

# from cycler import cycler

# def coef_plotter(alphas, coefs, feature_names, to_alpha, regtype='ridge'):
    
#     # Get the full range of alphas before subsetting to keep the plots from 
#     # resetting axes each time. (We use these values to set static axes later).
#     amin = np.min(alphas)
#     amax = np.max(alphas)
    
#     # Subset the alphas and coefficients to just the ones below the set limit
#     # from the interactive widget:
#     alphas = [a for a in alphas if a <= to_alpha]
#     coefs = coefs[0:len(alphas)]
    
#     # Get some colors from seaborn:
#     colors = sns.color_palette("husl", len(coefs[0]))
    
#     # Get the figure and reset the size to be wider:
#     fig = plt.figure()
#     fig.set_size_inches(18,5)

#     # We have two axes this time on our figure. 
#     # The fig.add_subplot adds axes to our figure. The number inside stands for:
#     #[figure_rows|figure_cols|position_of_current_axes]
#     ax1 = fig.add_subplot(121)
    
#     # Give it the color cycler:
#     ax1.set_prop_cycle(cycler('color', colors))
    
#     # Print a vertical line showing our current alpha threshold:
#     ax1.axvline(to_alpha, lw=2, ls='dashed', c='k', alpha=0.4)
    
#     # Plot the lines of the alphas on x-axis and coefficients on y-axis
#     ax1.plot(alphas, coefs, lw=2)
    
#     # set labels for axes:
#     ax1.set_xlabel('alpha', fontsize=20)
#     ax1.set_ylabel('coefficients', fontsize=20)
    
#     # If this is for the ridge, set this to a log scale on the x-axis:
#     if regtype == 'ridge':
#         ax1.set_xscale('log')
    
#     # Enforce the axis limits:
#     ax1.set_xlim([amin, amax])
    
#     # Put a title on the axis
#     ax1.set_title(regtype+' coef paths\n', fontsize=20)
    
#     # Get the ymin and ymax for this axis to enforce it to be the same on the 
#     # second chart:
#     ymin, ymax = ax1.get_ylim()

#     # Add our second axes for the barplot in position 2:
#     ax2 = fig.add_subplot(122)
    
#     # Position the bars according to their index from the feature names variable:
#     ax2.bar(list(range(1, len(feature_names)+1)), coefs[-1], align='center', color=colors)
#     ax2.set_xticks(list(range(1, len(feature_names)+1)))
    
#     # Reset the ticks from numbers to acutally be the names:
#     ax2.set_xticklabels(feature_names, rotation=65, fontsize=12)
    
#     # enforce limits and add titles, labels
#     ax2.set_ylim([ymin, ymax])
#     ax2.set_title(regtype+' predictor coefs\n', fontsize=20)
#     ax2.set_xlabel('coefficients', fontsize=20)
#     ax2.set_ylabel('alpha', fontsize=20)
    
#     plt.show()

# %%
from ipywidgets import *
from IPython.display import display

def ridge_plot_runner(log_of_alpha=0):
    coef_plotter(r_alphas, r_coefs, X.columns, 10**log_of_alpha, regtype='ridge')

interact(ridge_plot_runner, log_of_alpha=(0.1,5,0.2))

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

# %%
def lasso_coefs(X, y, alphas):
    coefs = []
    lasso_reg = Lasso()
    for a in alphas:
        lasso_reg.set_params(alpha=a)
        lasso_reg.fit(X, y)
        coefs.append(lasso_reg.coef_)
    return coefs

# %%
l_alphas = np.arange(0.001, 0.15, 0.0025)
l_coefs = lasso_coefs(X, y, l_alphas)

# %%
def lasso_plot_runner(alpha=0):
    coef_plotter(l_alphas, l_coefs, X.columns, alpha, regtype='lasso')

interact(lasso_plot_runner, alpha=(0.001,0.2,0.01))

# %% [markdown]
# ### Correlation: Overall_Quality

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr()[['sale_price']].sort_values('sale_price'), annot=True)

# %%
sns.pairplot(df, y_vars=['overall_qual', 'garage_cars', 'garage_area'], x_vars=['sale_price'])

# %%
df.hist(figsize=(15, 15));

# %% [markdown]
# ### Box Plot Target

# %%
sns.boxplot(df['sale_price'])

# %%
sns.boxplot(df['overall_qual'])

# %% [markdown]
# ## Model Prep (Create our features matrix (X) and target vector (y))

# %%
# X = df[['lot_area','full_bath', 'overall_qual']]
# features = [col for col in df._get_numeric_data().columns if col != 'sale_price']
# X = df[features]
X = df[['lot_area','full_bath', 'overall_qual']]
y = df['sale_price']

# %% [markdown]
# ## Model Prep (Train / Test Split)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %% [markdown]
# ## Model Prep: Scaling

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %% [markdown]
# ## Model Prep: Instantiate our models

# %%
lr = LinearRegression()

# %%
lasso = LassoCV(n_alphas=100)

# %%
ridge = RidgeCV(alphas=np.linspace(.1, 10, 100))

# %% [markdown]
# ## Cross Validation

# %%
lr_scores = cross_val_score(lr, X_train_sc, y_train, cv=3)
lr_scores.mean()

# %%
lasso_scores = cross_val_score(lasso, X_train_sc, y_train, cv=3)
lasso_scores.mean()

# %%
ridge_scores = cross_val_score(ridge, X_train_sc, y_train, cv=3)
ridge_scores.mean()

# %% [markdown]
# ## Model Fitting & Evaluation

# %% [markdown]
# ### Lasso Train

# %%
lasso.fit(X_train_sc, y_train)
lasso.score(X_train_sc, y_train)

# %% [markdown]
# ### Lasso Test

# %%
lasso.score(X_test_sc,y_test) # make sure you scale

# %% [markdown]
# ### Ridge Train

# %%
ridge.fit(X_train_sc, y_train)
ridge.score(X_train_sc, y_train)

# %% [markdown]
# ### Ridge Test

# %%
ridge.score(X_test_sc, y_test)

# %%
pd.Series(ridge.coef_).plot.bar(figsize=(15, 7))

# %% [markdown]
# ### Scores (Train Test Split)

# %%
lr = LinearRegression()

# %%
ss = StandardScaler()

# %%
ss.fit(X_train)

# %%
X_train_sc = ss.transform(X_train)

# %%
X_test_sc = ss.transform(X_test)

# %%
lr.fit(X_train_sc, y_train)

# %%
lr.score(X_train_sc, y_train)

# %%
lr.score(X_test_sc,y_test)

# %% [markdown]
# ### Scores (No Train Test Split)

# %%
lr.fit(X,y)

# %%
lr.score(X,y)

# %% [markdown]
# ### Scores Training (not Scaled)

# %%
lr.fit(X_train, y_train)

# %%
lr.score(X_train, y_train)

# %%
lr.score(X_test,y_test)

# %% [markdown]
# ```
# test for colinearity
#
# which variables are colinear?
#
# what are the beta weights
#
# what are the most important things to say here?
#
# variance threshold.....
#
# feature selection
#
# zero out the features using lasso.
# ```

# %% [markdown]
# ### 11. Build what you think may be the best MLR model predicting `price`.
#
# The independent variables are your choice, but *include at least three variables.* At least one of which should be a dummy-coded variable (either one we created before or a new one).
#
# To construct your model don't forget to load in the statsmodels api:
#
# ```python
# from sklearn.linear_model import LinearRegression
#
# model = LinearRegression()
# ```
